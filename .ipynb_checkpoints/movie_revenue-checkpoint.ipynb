# %% [markdown]
# ## Analysis of movie revenue dataset ##

# %%
#import libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.linear_model import LinearRegression
plt.style.use("ggplot")

# %%
# %matplotlib notebook

# %%
#read in data
df = pd.read_csv("tmdb_5000_movies.csv")

#removing columns which are either useless or too vague
df.drop(["overview", "popularity", "homepage", "status", "original_title", "tagline"], axis=1, inplace = True)

#adding ratio column, removing inf and nan values
df["bdgt_2_rev"] = df["revenue"] / df["budget"]
df = df.replace([np.inf, -np.inf], np.nan).dropna()
df = df[df["bdgt_2_rev"] <= 1]
df.head()
# Out:
#         budget                                             genres     id  \
# 13   255000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  57201
# 73   175000000  [{"id": 14, "name": "Fantasy"}, {"id": 35, "na...   2698
# 83    27000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  79698
# 84   175000000  [{"id": 18, "name": "Drama"}, {"id": 28, "name...  64686
# 135  150000000  [{"id": 18, "name": "Drama"}, {"id": 27, "name...   7978
#
#                                               keywords original_language  \
# 13   [{"id": 1556, "name": "texas"}, {"id": 2673, "...                en
# 73   [{"id": 494, "name": "father son relationship"...                en
# 83                                                  []                en
# 84   [{"id": 233, "name": "japan"}, {"id": 236, "na...                en
# 135  [{"id": 494, "name": "father son relationship"...                en
#
#                                   production_companies  \
# 13   [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 73   [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 83   [{"name": "Corsan", "id": 7299}, {"name": "Bli...
# 84   [{"name": "Mid Atlantic Films", "id": 2735}, {...
# 135  [{"name": "Universal Pictures", "id": 33}, {"n...
#
#                                   production_countries release_date  \
# 13   [{"iso_3166_1": "US", "name": "United States o...   2013-07-03
# 73   [{"iso_3166_1": "US", "name": "United States o...   2007-06-09
# 83   [{"iso_3166_1": "AU", "name": "Australia"}, {"...   2015-02-13
# 84   [{"iso_3166_1": "US", "name": "United States o...   2013-12-06
# 135  [{"iso_3166_1": "US", "name": "United States o...   2010-02-11
#
#        revenue  runtime                                   spoken_languages  \
# 13    89289910    149.0           [{"iso_639_1": "en", "name": "English"}]
# 73   173000000     96.0           [{"iso_639_1": "en", "name": "English"}]
# 83           0    109.0           [{"iso_639_1": "en", "name": "English"}]
# 84   150962475    119.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 135          0    102.0           [{"iso_639_1": "en", "name": "English"}]
#
#                title  vote_average  vote_count  bdgt_2_rev
# 13   The Lone Ranger           5.9        2311    0.350157
# 73     Evan Almighty           5.3        1151    0.988571
# 83        The Lovers           4.8          34    0.000000
# 84          47 Ronin           5.9        1326    0.862643
# 135      The Wolfman           5.5         549    0.000000

# %%
fig = plt.figure()

ax = fig.add_subplot(2, 2, 1)
plt.plot(df["budget"], df["revenue"], marker = ".", linestyle = "")
plt.xlabel("Film Budget")
plt.ylabel("Film Revenue")

ax = fig.add_subplot(2, 2, 2)
plt.plot(df["vote_average"], df["revenue"], marker = ".", linestyle = "")
plt.xlabel("Average Film Score")
plt.ylabel("Film Revenue")

ax = fig.add_subplot(2, 2, 3)
plt.plot(df["runtime"], df["revenue"], marker = ".", linestyle = "")
plt.xlabel("Runtime")
plt.ylabel("Film Revenue")

ax = fig.add_subplot(2, 2, 4)
plt.plot(df["bdgt_2_rev"], df["vote_average"], marker = ".", linestyle = "")
plt.xlabel("Budget to Revenue ratio")
plt.ylabel("Average Film Score")

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Question 1:
# ### Is there a correlation between movie financial sucess and critical success?
#
# For this, we will define financial success as the budget to revenue ratio (a film with ratio 1 has broken even, a film with ratio greater than 1 has made profit) and the critical success as the average movie score out of 10.
